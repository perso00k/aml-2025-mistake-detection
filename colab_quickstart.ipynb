# %% [markdown]
# # Colab Quickstart

# %%
# !git clone --recursive https://github.com/perso00k/aml-2025-mistake-detection.git code

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mkdir -p code/data/video
# !mkdir -p code/checkpoints

path_omnivore = "/content/drive/MyDrive/AML_Project/omnivore.zip"
path_slowfast = "/content/drive/MyDrive/AML_Project/slowfast.zip"
path_checkpoints = "/content/drive/MyDrive/AML_Project/error_recognition_best.zip"

print("Estrazione features Omnivore in corso...")
# !unzip -q "$path_omnivore" -d code/data/video/

print("Estrazione features SlowFast in corso...")
# !unzip -q "$path_slowfast" -d code/data/video/

print("Estrazione checkpoint in corso...")
# !unzip -q "$path_checkpoints" -d code/checkpoints/

# %%
# !pip install torcheval

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant MLP --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/MLP/omnivore/error_recognition_MLP_omnivore_step_epoch_43.pt \
#   --split step --threshold 0.6
