# %%
# !git clone --recursive https://github.com/perso00k/aml-2025-mistake-detection.git code
# Out:
# Cloning into 'code'...
# remote: Enumerating objects: 1291, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 1291 (delta 8), reused 56 (delta 6), pack-reused 1224 (from 2)
# Receiving objects: 100% (1291/1291), 1.67 GiB | 16.07 MiB/s, done.
# Resolving deltas: 100% (298/298), done.
# Submodule 'annotations' (https://github.com/CaptainCook4D/annotations) registered for path 'annotations'
# Cloning into '/content/code/annotations'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 152 (delta 75), reused 108 (delta 46), pack-reused 0 (from 0)
# Receiving objects: 100% (152/152), 793.14 KiB | 3.18 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Submodule path 'annotations': checked out '0e9a108be2cbcbcbd592e7418c0ab9c16232d27a'

# %%
# !pip install decord
# !pip install timm
# !pip install regex ftfy
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 150.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.5 MB/s eta 0:00:00
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
from google.colab import drive
import os

# Monta Google Drive per accedere al dataset zip e salvare i risultati
drive.mount('/content/drive')

# --- CONFIGURAZIONE PERCORSI ---
# Modifica questi percorsi in base a dove hai i file su Drive
DRIVE_BASE_PATH = "/content/drive/MyDrive/AML_Project_resized_ds" # La cartella del tuo progetto su Drive
DATASET_ZIP_PATH = os.path.join(DRIVE_BASE_PATH, "captain_cook_4d_gopro_resized.zip") # Il dataset zip
OUTPUT_FEATURES_PATH = os.path.join(DRIVE_BASE_PATH, "features_PE") # Dove salvare i .pt

# Crea la cartella di output se non esiste
os.makedirs(OUTPUT_FEATURES_PATH, exist_ok=True)
print(f"Drive montato. Dataset atteso in: {DATASET_ZIP_PATH}")
print(f"Output feature impostato su: {OUTPUT_FEATURES_PATH}")
# Out:
# Mounted at /content/drive
# Drive montato. Dataset atteso in: /content/drive/MyDrive/AML_Project_resized_ds/captain_cook_4d_gopro_resized.zip
# Output feature impostato su: /content/drive/MyDrive/AML_Project_resized_ds/features_PE

# %%
# %mkdir code/videos

# %%
# !unzip -q "$DATASET_ZIP_PATH" -d "code/videos"

# %%
# %cd code
# Out:
# /content/code

# %%
import sys
import os

# Ci spostiamo nella cartella con lo script e il core
os.chdir("/content/code/feature_extraction")

LOCAL_VIDEO_DIR = "/content/code/videos"

# Parametri
MODEL_NAME = "PE-Core-B16-224" # Usa "PE-Core-L14-336" se hai una GPU A100/V100
BATCH_SIZE = 32
FPS = 2.0

print("Avvio estrazione...")
print(f"Modello: {MODEL_NAME}")
print(f"Video Source: {LOCAL_VIDEO_DIR}")
print(f"Output Drive: {OUTPUT_FEATURES_PATH}")

# Eseguiamo lo script Python
# !python feature_extraction.py \
  --video_dir "{LOCAL_VIDEO_DIR}" \
  --output_dir "{OUTPUT_FEATURES_PATH}" \
  --batch_size {BATCH_SIZE} \
  --fps {FPS} \
  --model {MODEL_NAME}
# Out:
# Avvio estrazione...
# Modello: PE-Core-B16-224
# Video Source: /content/code/videos
# Output Drive: /content/drive/MyDrive/AML_Project_resized_ds/features_PE
# Leggo video da: /content/code/videos
# Salvo feature in: /content/drive/MyDrive/AML_Project_resized_ds/features_PE
# Caricamento modello: PE-Core-B16-224...
# PE-Core-B16-224.pt: 100% 1.79G/1.79G [00:32<00:00, 55.3MB/s]
# Missing keys for loading model: []
# Unexpected keys for loading model: []
# Trovati 384 video.
#  99% 379/384 [4:36:42<05:15, 63.05s/it]
