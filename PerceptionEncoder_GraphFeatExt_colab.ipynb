# %%
# !git clone --recursive https://github.com/perso00k/aml-2025-mistake-detection.git code

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mkdir code/graphs

path_graphs = "/content/drive/MyDrive/AML_Project/graphs.zip"

# !unzip -q "$path_graphs" -d code/graphs

# %%
import os

# 1. Move to the feature_extraction directory
os.chdir("/content/code/feature_extraction")

# 2. Define directories
GRAPHS_DIR = "/content/code/graphs"       # Input: JSON files location
OUTPUT_DIR = "/content/code/data/text"  # Output: .npz files location

print(f"Input Directory: {GRAPHS_DIR}")
print(f"Output Directory: {OUTPUT_DIR}")

# 3. Run the script (Batch Mode)
# !python extract_graph_text_features.py \
  --graphs_dir "{GRAPHS_DIR}" \
  --output_dir "{OUTPUT_DIR}" \
  --model "PE-Core-B16-224"
